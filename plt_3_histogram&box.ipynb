# %%
#直方图
import pandas as pd
import matplotlib.pyplot as plt
from numpy import arange

reviews = pd.read_csv("fandango_score_comparison.csv")
cols = ["FILM", "RT_user_norm", "Metacritic_user_nom", "IMDB_norm", "Fandango_Ratingvalue","Fandango_Stars"]
norm_reviews = reviews[cols]
num_cols = ["RT_user_norm", "Metacritic_user_nom", "IMDB_norm", "Fandango_Ratingvalue","Fandango_Stars"]

fig, ax = plt.subplots()
#ax.hist(norm_reviews["Fandango_Ratingvalue"])
#ax.hist(norm_reviews["Fandango_Ratingvalue"], bins = 20) #bins是指定有多少个柱子
#ax.hist(norm_reviews["Fandango_Ratingvalue"], range= (4,5), bins = 20)  #range=(4,5)指只显示4和5之间的
#ax.set_ylim(0:50)可以指定y轴的区间
plt.show()

# %%
#盒图
fig, ax = plt.subplots()
ax.boxplot(norm_reviews["RT_user_norm"])
ax.set_xticklabels(["RottenTomatoes"])
ax.set_ylim(0, 5)
plt.show()

# %%
fig, ax = plt.subplots()
ax.boxplot(norm_reviews[num_cols].values)
ax.set_xticklabels(num_cols, rotation = 90)
ax.set_ylim(0, 6)
plt.show()
